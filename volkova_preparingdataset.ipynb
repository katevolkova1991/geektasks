# %% [markdown]
# # Предобработка данных.

# %% [markdown]
# **Подключение библиотек и скриптов**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Пути к директориям и файлам**

# %%
DATASET_PATH = './train.csv'
PREPARED_DATASET_PATH = './train_prepared.csv'

# %% [markdown]
# ### Загрузка данных

# %% [markdown]
# **Описание датасета**
#
# Описание датасета:
# * **Id** - идентификационный номер квартиры
# * **DistrictId** - идентификационный номер района
# * **Rooms** - количество комнат
# * **Square** - площадь
# * **LifeSquare** - жилая площадь
# * **KitchenSquare** - площадь кухни
# * **Floor** - этаж
# * **HouseFloor** - количество этажей в доме
# * **HouseYear** - год постройки дома
# * **Ecology_1, Ecology_2, Ecology_3** - экологические показатели местности
# * **Social_1, Social_2, Social_3** - социальные показатели местности
# * **Healthcare_1, Helthcare_2** - показатели местности, связанные с охраной здоровья
# * **Shops_1, Shops_2** - показатели, связанные с наличием магазинов, торговых центров
# * **Price** - цена квартиры

# %%
df = pd.read_csv(DATASET_PATH, index_col='Id')
df.head()
# Out:
#        DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 14038          35    2.0  47.981561   29.442751            6.0      7
# 15053          41    3.0  65.683640   40.049543            8.0      7
# 4765           53    2.0  44.947953   29.197612            0.0      8
# 5809           58    2.0  53.352981   52.731512            9.0      8
# 10783          99    1.0  39.649192   23.776169            7.0     11
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# Id
# 14038         9.0       1969   0.089040         B         B        33
# 15053         9.0       1978   0.000070         B         B        46
# 4765         12.0       1968   0.049637         B         B        34
# 5809         17.0       1977   0.437885         B         B        23
# 10783        12.0       1976   0.012339         B         B        35
#
#        Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# Id
# ...

# %%
df.shape
# Out:
# (10000, 19)

# %% [markdown]
# ### Получение информации о данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 14038 to 6306
# Data columns (total 19 columns):
# DistrictId       10000 non-null int64
# Rooms            10000 non-null float64
# Square           10000 non-null float64
# LifeSquare       7887 non-null float64
# KitchenSquare    10000 non-null float64
# Floor            10000 non-null int64
# HouseFloor       10000 non-null float64
# HouseYear        10000 non-null int64
# Ecology_1        10000 non-null float64
# Ecology_2        10000 non-null object
# Ecology_3        10000 non-null object
# Social_1         10000 non-null int64
# Social_2         10000 non-null int64
# Social_3         10000 non-null int64
# Healthcare_1     5202 non-null float64
# Helthcare_2      10000 non-null int64
# Shops_1          10000 non-null int64
# Shops_2          10000 non-null object
# Price            10000 non-null float64
# dtypes: float64(8), int64(8), object(3)
# memory usage: 1.5+ MB

# %%
df.dtypes
# Out:
# DistrictId         int64
# Rooms            float64
# Square           float64
# LifeSquare       float64
# KitchenSquare    float64
# Floor              int64
# HouseFloor       float64
# HouseYear          int64
# Ecology_1        float64
# Ecology_2         object
# Ecology_3         object
# Social_1           int64
# Social_2           int64
# Social_3           int64
# Healthcare_1     float64
# Helthcare_2        int64
# Shops_1            int64
# Shops_2           object
# Price            float64
# dtype: object

# %%
df.describe()
# Out:
#          DistrictId         Rooms        Square   LifeSquare  KitchenSquare  \
# count  10000.000000  10000.000000  10000.000000  7887.000000   10000.000000
# mean      50.400800      1.890500     56.315775    37.199645       6.273300
# std       43.587592      0.839512     21.058732    86.241209      28.560917
# min        0.000000      0.000000      1.136859     0.370619       0.000000
# 25%       20.000000      1.000000     41.774881    22.769832       1.000000
# 50%       36.000000      2.000000     52.513310    32.781260       6.000000
# 75%       75.000000      2.000000     65.900625    45.128803       9.000000
# max      209.000000     19.000000    641.065193  7480.592129    2014.000000
#
#               Floor    HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.000000  1.000000e+04  10000.000000  10000.000000
# mean       8.526700     12.609400  3.990166e+03      0.118858     24.687000
# ...

# %%
df.describe(include='object')
# Out:
#        Ecology_2 Ecology_3 Shops_2
# count      10000     10000   10000
# unique         2         2       2
# top            B         B       B
# freq        9903      9725    9175

# %%
df['Ecology_2'].value_counts()
# Out:
# B    9903
# A      97
# Name: Ecology_2, dtype: int64

# %%
df['Ecology_3'].value_counts()
# Out:
# B    9725
# A     275
# Name: Ecology_3, dtype: int64

# %%
df['Shops_2'].value_counts()
# Out:
# B    9175
# A     825
# Name: Shops_2, dtype: int64

# %% [markdown]
# ### Обработка пропусков

# %%
df.isna().sum()
# Out:
# DistrictId          0
# Rooms               0
# Square              0
# LifeSquare       2113
# KitchenSquare       0
# Floor               0
# HouseFloor          0
# HouseYear           0
# Ecology_1           0
# Ecology_2           0
# Ecology_3           0
# Social_1            0
# Social_2            0
# Social_3            0
# Healthcare_1     4798
# Helthcare_2         0
# Shops_1             0
# Shops_2             0
# Price               0
# dtype: int64

# %%
round(df.isna().sum() * 100 / df.shape[0], 1)
# Out:
# DistrictId        0.0
# Rooms             0.0
# Square            0.0
# LifeSquare       21.1
# KitchenSquare     0.0
# Floor             0.0
# HouseFloor        0.0
# HouseYear         0.0
# Ecology_1         0.0
# Ecology_2         0.0
# Ecology_3         0.0
# Social_1          0.0
# Social_2          0.0
# Social_3          0.0
# Healthcare_1     48.0
# Helthcare_2       0.0
# Shops_1           0.0
# Shops_2           0.0
# Price             0.0
# dtype: float64

# %% [markdown]
# **LifeSquare**

# %%
df['LifeSquare'].fillna(df['LifeSquare'].median(), inplace=True)

# %%
df['LifeSquare'].describe()
# Out:
# count    10000.000000
# mean        36.266040
# std         76.609981
# min          0.370619
# 25%         25.527399
# 50%         32.781260
# 75%         41.427234
# max       7480.592129
# Name: LifeSquare, dtype: float64

# %% [markdown]
# **Healthcare_1**

# %%
df['Healthcare_1'].fillna(df['Healthcare_1'].median(), inplace=True)

# %%
df['Healthcare_1'].describe()
# Out:
# count    10000.000000
# mean      1026.358900
# std        746.662828
# min          0.000000
# 25%        830.000000
# 50%        900.000000
# 75%        990.000000
# max       4849.000000
# Name: Healthcare_1, dtype: float64

# %%
df.isna().sum()
# Out:
# DistrictId       0
# Rooms            0
# Square           0
# LifeSquare       0
# KitchenSquare    0
# Floor            0
# HouseFloor       0
# HouseYear        0
# Ecology_1        0
# Ecology_2        0
# Ecology_3        0
# Social_1         0
# Social_2         0
# Social_3         0
# Healthcare_1     0
# Helthcare_2      0
# Shops_1          0
# Shops_2          0
# Price            0
# dtype: int64

# %% [markdown]
# ### Обработка выбросов

# %%
df.describe()
# Out:
#          DistrictId         Rooms        Square    LifeSquare  KitchenSquare  \
# count  10000.000000  10000.000000  10000.000000  10000.000000   10000.000000
# mean      50.400800      1.890500     56.315775     36.266040       6.273300
# std       43.587592      0.839512     21.058732     76.609981      28.560917
# min        0.000000      0.000000      1.136859      0.370619       0.000000
# 25%       20.000000      1.000000     41.774881     25.527399       1.000000
# 50%       36.000000      2.000000     52.513310     32.781260       6.000000
# 75%       75.000000      2.000000     65.900625     41.427234       9.000000
# max      209.000000     19.000000    641.065193   7480.592129    2014.000000
#
#               Floor    HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.000000  1.000000e+04  10000.000000  10000.000000
# mean       8.526700     12.609400  3.990166e+03      0.118858     24.687000
# ...

# %%
df['LifeSquare'].describe()
# Out:
# count    10000.000000
# mean        36.266040
# std         76.609981
# min          0.370619
# 25%         25.527399
# 50%         32.781260
# 75%         41.427234
# max       7480.592129
# Name: LifeSquare, dtype: float64

# %%
df[(df['LifeSquare'] > 641)]
# Out:
#        DistrictId  Rooms     Square   LifeSquare  KitchenSquare  Floor  \
# Id
# 16550          27    3.0  81.694417  7480.592129            1.0      9
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# Id
# 16550        17.0       2016   0.017647         B         B         2
#
#        Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# Id
# 16550       469         0         900.0            0        0       B
#
#                Price
# Id
# 16550  217357.492366

# %%
df.loc[df['LifeSquare'] > 641, 'LifeSquare'] = df.loc[df['LifeSquare'] > 641, 'LifeSquare'] / 100
df.describe()
# Out:
#          DistrictId         Rooms        Square    LifeSquare  KitchenSquare  \
# count  10000.000000  10000.000000  10000.000000  10000.000000   10000.000000
# mean      50.400800      1.890500     56.315775     35.525462       6.273300
# std       43.587592      0.839512     21.058732     18.064768      28.560917
# min        0.000000      0.000000      1.136859      0.370619       0.000000
# 25%       20.000000      1.000000     41.774881     25.527399       1.000000
# 50%       36.000000      2.000000     52.513310     32.781260       6.000000
# 75%       75.000000      2.000000     65.900625     41.427234       9.000000
# max      209.000000     19.000000    641.065193    638.163193    2014.000000
#
#               Floor    HouseFloor     HouseYear     Ecology_1      Social_1  \
# count  10000.000000  10000.000000  1.000000e+04  10000.000000  10000.000000
# mean       8.526700     12.609400  3.990166e+03      0.118858     24.687000
# ...

# %% [markdown]
# **KitchenSquare**

# %%
df[(df['KitchenSquare'] > 641)]
# Out:
#        DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 14656          62    1.0  47.100719   46.447960         2014.0      4
# 14679          81    1.0  32.276663   19.278394         1970.0      6
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# Id
# 14656         1.0       2014   0.072158         B         B         2
# 14679         1.0       1977   0.006076         B         B        30
#
#        Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2  \
# Id
# 14656       629         1         900.0            0        0       A
# 14679      5285         0         645.0            6        6       B
#
#                Price
# Id
# 14656  108337.484207
# 14679  105539.556275

# %%
df[['LifeSquare', 'KitchenSquare', 'Square']].describe()
# Out:
#          LifeSquare  KitchenSquare        Square
# count  10000.000000   10000.000000  10000.000000
# mean      35.525462       6.273300     56.315775
# std       18.064768      28.560917     21.058732
# min        0.370619       0.000000      1.136859
# 25%       25.527399       1.000000     41.774881
# 50%       32.781260       6.000000     52.513310
# 75%       41.427234       9.000000     65.900625
# max      638.163193    2014.000000    641.065193

# %% [markdown]
# ### Построение новых признаков

# %% [markdown]
# **Преобразуем категориальный признаки в несколько бинарных**

# %%
df['Ecology_2'].value_counts()
# Out:
# B    9903
# A      97
# Name: Ecology_2, dtype: int64

# %% [markdown]
# ![](oh.png)

# %%
ecology2_pr = pd.get_dummies(df['Ecology_2'], prefix='ec2')
ecology2_pr.head()
# Out:
#        ec2_A  ec2_B
# Id
# 14038      0      1
# 15053      0      1
# 4765       0      1
# 5809       0      1
# 10783      0      1

# %%
ecology3_pr = pd.get_dummies(df['Ecology_3'], prefix='ec3')
ecology3_pr.head()
# Out:
#        ec3_A  ec3_B
# Id
# 14038      0      1
# 15053      0      1
# 4765       0      1
# 5809       0      1
# 10783      0      1

# %%
shops2_pr = pd.get_dummies(df['Shops_2'], prefix='sh2')
shops2_pr.head()
# Out:
#        sh2_A  sh2_B
# Id
# 14038      0      1
# 15053      0      1
# 4765       0      1
# 5809       0      1
# 10783      0      1

# %%
df[ecology2_pr.columns] = ecology2_pr
df[ecology3_pr.columns] = ecology3_pr
df[shops2_pr.columns] = shops2_pr

# %%
df.isna().sum()
# Out:
# DistrictId       0
# Rooms            0
# Square           0
# LifeSquare       0
# KitchenSquare    0
# Floor            0
# HouseFloor       0
# HouseYear        0
# Ecology_1        0
# Ecology_2        0
# Ecology_3        0
# Social_1         0
# Social_2         0
# Social_3         0
# Healthcare_1     0
# Helthcare_2      0
# Shops_1          0
# Shops_2          0
# Price            0
# ec2_A            0
# ec2_B            0
# ec3_A            0
# ec3_B            0
# sh2_A            0
# sh2_B            0
# dtype: int64

# %% [markdown]
# **Ковариация и корреляция данных**
#
# Используются для количественной оценки степени влияния признаков друг на друга.

# %% [markdown]
# Ковариация:
#
# $$cov(x,y)=\frac{\sum_i^n(x_i-\overline{x})(y_i-\overline{y})}{n-1}$$

# %%
df.cov()
# Out:
#                  DistrictId         Rooms        Square     LifeSquare  \
# DistrictId     1.899878e+03      2.613849 -2.442765e+01     -22.229696
# Rooms          2.613849e+00      0.704780  1.171932e+01       6.930105
# Square        -2.442765e+01     11.719321  4.434702e+02     249.834303
# LifeSquare    -2.222970e+01      6.930105  2.498343e+02     326.335839
# KitchenSquare  5.024179e+01      0.122839  5.003894e+00       5.870570
# Floor         -2.749915e+01     -0.002927  1.266967e+01       6.853788
# HouseFloor    -4.402185e+01     -0.166687  1.163017e+01       8.035822
# HouseYear      1.173708e+05  -1786.198010 -3.813425e+04  -30596.005159
# Ecology_1      3.387471e-01     -0.003232 -1.616182e-01      -0.105263
# Social_1       1.883481e+02      1.118338 -2.609987e+01     -24.752083
# Social_2       2.924961e+04    239.954731 -3.638403e+03   -4228.837486
# Social_3       1.413715e+02      0.256318  1.768620e+01      20.370943
# ...

# %% [markdown]
# Линейный коэффициент корреляции:
#
# $$R=\frac{cov(x,y)}{\sigma_x \sigma_y}$$

# %%
df.corr()
# Out:
#                DistrictId     Rooms    Square  LifeSquare  KitchenSquare  \
# DistrictId       1.000000  0.071432 -0.026613   -0.028232       0.040358
# Rooms            0.071432  1.000000  0.662893    0.456963       0.005123
# Square          -0.026613  0.662893  1.000000    0.656731       0.008320
# LifeSquare      -0.028232  0.456963  0.656731    1.000000       0.011378
# KitchenSquare    0.040358  0.005123  0.008320    0.011378       1.000000
# Floor           -0.120373 -0.000665  0.114791    0.072389      -0.011397
# HouseFloor      -0.149051 -0.029302  0.081505    0.065649       0.000780
# HouseYear        0.013430 -0.010612 -0.009032   -0.008447       0.000958
# Ecology_1        0.065294 -0.032347 -0.064479   -0.048956      -0.005622
# Social_1         0.246463  0.075980 -0.070690   -0.078151       0.043379
# Social_2         0.167479  0.071335 -0.043120   -0.058424       0.037805
# Social_3         0.136095  0.012811  0.035241    0.047317      -0.015140
# ...

# %%
df.corr()['Price'].sort_values()
# Out:
# sh2_A           -0.070388
# Ecology_1       -0.058381
# ec3_B           -0.052585
# ec2_A           -0.022379
# HouseYear        0.004305
# ec2_B            0.022379
# KitchenSquare    0.028864
# ec3_A            0.052585
# sh2_B            0.070388
# Social_3         0.074878
# HouseFloor       0.088280
# Healthcare_1     0.128059
# Floor            0.128715
# Shops_1          0.180876
# Social_2         0.239226
# Helthcare_2      0.253090
# Social_1         0.263286
# DistrictId       0.265100
# LifeSquare       0.330769
# Square           0.520075
# Rooms            0.550291
# Price            1.000000
# Name: Price, dtype: float64

# %% [markdown]
# **Построим новые признаки**

# %% [markdown]
# ### Сохранение результатов

# %%
df.head()
# Out:
#        DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# Id
# 14038          35    2.0  47.981561   29.442751            6.0      7
# 15053          41    3.0  65.683640   40.049543            8.0      7
# 4765           53    2.0  44.947953   29.197612            0.0      8
# 5809           58    2.0  53.352981   52.731512            9.0      8
# 10783          99    1.0  39.649192   23.776169            7.0     11
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2  ... Helthcare_2  Shops_1  \
# Id                                                 ...
# 14038         9.0       1969   0.089040         B  ...           0       11
# 15053         9.0       1978   0.000070         B  ...           1       16
# 4765         12.0       1968   0.049637         B  ...           1        3
# 5809         17.0       1977   0.437885         B  ...           0        5
# 10783        12.0       1976   0.012339         B  ...           2        4
#
# ...

# %%
df.to_csv(PREPARED_DATASET_PATH, index=False, encoding='utf-8')
